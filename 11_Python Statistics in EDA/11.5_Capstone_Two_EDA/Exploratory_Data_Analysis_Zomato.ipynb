# %% [markdown]
# ## Step 1 Import libraries and Load Data
# 1. Start by importing the necessary libraries for data analysis and visualization, such as pandas, numpy, matplotlib, and seaborn.
# 2. Load your dataset into a pandas DataFrame

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Step 2: Build Data Profiles and Tables
# 1. Get a high-level overview of your data by examining the dimensions, size, and basic statistics of the dataset using functions like shape, head(), describe(), and info().
# 2. Identify missing values and handle them appropriately using methods like isnull(), fillna(), or dropna().

# %%
df1=pd.read_csv('data/zomato.csv',encoding='ISO-8859-1')

df1.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df1.shape
# Out:
# (9551, 21)

# %%
df1.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df1.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
df1.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
df_country = pd.read_excel('data/Country-Code.xlsx')
df_country.head()
# Out:
#    Country Code    Country
# 0             1      India
# 1            14  Australia
# 2            30     Brazil
# 3            37     Canada
# 4            94  Indonesia

# %%
# Merge datasets
df=pd.merge(df1, df_country, on= 'Country Code', how= 'left')   #so we can get a final df with country name
df.head(2)
# Out:
#    Restaurant ID   Restaurant Name  Country Code         City  \
# 0        6317637  Le Petit Souffle           162  Makati City
# 1        6304287  Izakaya Kikufuji           162  Makati City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
#
#                      Cuisines  ...  Has Table booking Has Online delivery  \
# 0  French, Japanese, Desserts  ...                Yes                  No
# 1                    Japanese  ...                Yes                  No
#
# ...

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %%
df.drop(['Restaurant ID', 'Country Code', 'Locality Verbose', 'Longitude', 'Latitude'],axis=1,
inplace=True)

# %%
df.head(2)
# Out:
#     Restaurant Name         City  \
# 0  Le Petit Souffle  Makati City
# 1  Izakaya Kikufuji  Makati City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
#
#                                      Locality                    Cuisines  \
# 0   Century City Mall, Poblacion, Makati City  French, Japanese, Desserts
# 1  Little Tokyo, Legaspi Village, Makati City                    Japanese
#
#    Average Cost for two          Currency Has Table booking  \
# 0                  1100  Botswana Pula(P)               Yes
# 1                  1200  Botswana Pula(P)               Yes
#
#   Has Online delivery Is delivering now Switch to order menu  Price range  \
# 0                  No                No                   No            3
# 1                  No                No                   No            3
#
# ...

# %% [markdown]
# ## Step 3: Inferential Statistics
# 1. Perform inferential statistics to gain insights into your data
# 2. Identify any abnormal or unusual results in your dataset
# 3. Formulate null and alternative hypothesis to test based on your understanding of the data and main question.

# %%
# Top 3 countries that uses zomato
top_3 = df['Country'].value_counts()[:3]
top_3
# Out:
# India             8652
# United States      434
# United Kingdom      80
# Name: Country, dtype: int64

# %%
# Plot pie chart
plt.pie(top_3,labels=top_3.index)
circle = plt.Circle( (0,0), 0.5, color='white')    #Creating a Circle
p=plt.gcf()                                        #Adding circle to the Pie Chart
p.gca().add_artist(circle)
plt.title("Top 3 countries that uses zomato")      #Add title

plt.show()

# %%
# Top 10 Countries that uses zomator
top_10 = df['Country'].value_counts()[:10].rename_axis('Country').reset_index(name='count')
top_10.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_e23be_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_e23be_row1_col1 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_e23be_row2_col1, #T_e23be_row3_col1, #T_e23be_row4_col1, #T_e23be_row5_col1 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_e23be_row6_col1, #T_e23be_row7_col1, #T_e23be_row8_col1, #T_e23be_row9_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_e23be">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e23be_level0_col0" class="col_heading level0 col0" >Country</th>
#       <th id="T_e23be_level0_col1" class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e23be_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e23be_row0_col0" class="data row0 col0" >India</td>
#       <td id="T_e23be_row0_col1" class="data row0 col1" >8652</td>
# ...

# %%
# Countries with minimum interaction
df['Country'].value_counts()[-3:].rename_axis('Country').reset_index(name='count').style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_e2f2a_row0_col1, #T_e2f2a_row1_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_e2f2a_row2_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_e2f2a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e2f2a_level0_col0" class="col_heading level0 col0" >Country</th>
#       <th id="T_e2f2a_level0_col1" class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e2f2a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e2f2a_row0_col0" class="data row0 col0" >Qatar</td>
#       <td id="T_e2f2a_row0_col1" class="data row0 col1" >20</td>
#     </tr>
#     <tr>
#       <th id="T_e2f2a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e2f2a_row1_col0" class="data row1 col0" >Sri Lanka</td>
#       <td id="T_e2f2a_row1_col1" class="data row1 col1" >20</td>
#     </tr>
#     <tr>
# ...

# %%
# Most popular cuisines
popular_cuisines = df['Cuisines'].value_counts()[:10].rename_axis('Cuisines').reset_index(name='count')
popular_cuisines.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_0fe86_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_0fe86_row1_col1 {
#   background-color: #7cb7da;
#   color: #000000;
# }
# #T_0fe86_row2_col1, #T_0fe86_row3_col1 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_0fe86_row4_col1 {
#   background-color: #c9ddf0;
#   color: #000000;
# }
# #T_0fe86_row5_col1 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_0fe86_row6_col1 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_0fe86_row7_col1 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_0fe86_row8_col1 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_0fe86_row9_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_0fe86">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0fe86_level0_col0" class="col_heading level0 col0" >Cuisines</th>
# ...

# %% [markdown]
# ## Step 4: Explore Data Relationships
# 1. Use data visualization techniques to explore relationships between variables and compare them to the response variable.
# 2. Utilize matplotlib and seaborn functions to create various plots, such as scatter plots, line plots, histograms, or categorical plots, to visualize distributions, correlations, or group comparisons.

# %%
# Plot the most popular cuisines
plt.title('Most popular cuisines')

sns.scatterplot(y=popular_cuisines['Cuisines'], x=popular_cuisines['count'], hue=popular_cuisines['Cuisines'])
# Out:
# <Axes: title={'center': 'Most popular cuisines'}, xlabel='count', ylabel='Cuisines'>

# %% [markdown]
# The most popular are Chinese and North Indian cuisines.

# %%
# Analyzing "Has Online Delivery" column
df['Has Online delivery'].value_counts()
# Out:
# No     7100
# Yes    2451
# Name: Has Online delivery, dtype: int64

# %%
sns.countplot(x='Has Online delivery', data=df, palette=['red','green'])
# Out:
# <Axes: xlabel='Has Online delivery', ylabel='count'>

# %%
# Which countries do have online
df[df['Has Online delivery'] == 'Yes'].Country.value_counts()
# Out:
# India    2423
# UAE        28
# Name: Country, dtype: int64

# %%
sns.countplot(x='Rating color', data=df, palette = ['darkgreen','green','yellow','orange','grey','red'])
# Out:
# <Axes: xlabel='Rating color', ylabel='count'>

# %%
# Analyzing "Average Cost for two" column
by_rating = df.groupby(['Rating color']).mean().round()
by_rating
# Out:
#               Average Cost for two  Price range  Aggregate rating  Votes
# Rating color
# Dark Green                  8137.0          3.0               5.0  852.0
# Green                       3556.0          3.0               4.0  520.0
# Orange                       568.0          2.0               3.0   48.0
# Red                          638.0          2.0               2.0   91.0
# White                        340.0          1.0               0.0    1.0
# Yellow                      1045.0          2.0               4.0  229.0

# %%
plt.title('Aggregate rating vs Average Cost for two')
sns.barplot(x=by_rating['Aggregate rating'], y=by_rating['Average Cost for two'])
# Out:
# <Axes: title={'center': 'Aggregate rating vs Average Cost for two'}, xlabel='Aggregate rating', ylabel='Average Cost for two'>

# %% [markdown]
# Top rated restaurants have high average cost

# %%
# Analyzing Rating text column

plt.title('Rating text vs Average Cost for two')
sns.barplot(x = df['Rating text'], y=df['Average Cost for two'], palette = ['cyan', 'orange', 'red', 'green', 'blue', 'grey'])
# Out:
# <Axes: title={'center': 'Rating text vs Average Cost for two'}, xlabel='Rating text', ylabel='Average Cost for two'>

# %% [markdown]
# ## Step 5: Feature Selection and Engineering
# 1. Conduct feature selection to identify variables that are particularly significant in explaining the answer to your project question.
# 2. Consider feature engineering techniques like one-hot encoding for categorical variables, binarization, or creating new features based on domain knowledge.
# 3. Handle missing data appropriately through methods such as imputation, deletion, or analysis of missing patterns.
# 4. Apply transformations like standardization, log transformation, or normalization as needed.

# %%
# To create a table with selected features for better understanding
df.groupby(['Rating color','Aggregate rating', 'Rating text']).mean().style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_6f42d_row0_col0, #T_6f42d_row12_col0, #T_6f42d_row16_col0 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_6f42d_row0_col1 {
#   background-color: #2c7cba;
#   color: #f1f1f1;
# }
# #T_6f42d_row0_col2 {
#   background-color: #4b98ca;
#   color: #f1f1f1;
# }
# #T_6f42d_row1_col0 {
#   background-color: #135fa7;
#   color: #f1f1f1;
# }
# #T_6f42d_row1_col1, #T_6f42d_row4_col2 {
#   background-color: #1f6eb3;
#   color: #f1f1f1;
# }
# #T_6f42d_row1_col2 {
#   background-color: #4695c8;
#   color: #f1f1f1;
# }
# #T_6f42d_row2_col0, #T_6f42d_row10_col0, #T_6f42d_row11_col0, #T_6f42d_row14_col2, #T_6f42d_row17_col0, #T_6f42d_row18_col0, #T_6f42d_row24_col0, #T_6f42d_row25_col0 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_6f42d_row2_col1 {
#   background-color: #1561a9;
#   color: #f1f1f1;
# }
# #T_6f42d_row2_col2 {
#   background-color: #08488e;
#   color: #f1f1f1;
# }
# ...
